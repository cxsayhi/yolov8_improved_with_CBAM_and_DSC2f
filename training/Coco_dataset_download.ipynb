# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Image_rec/coco_dataset
# Out:
# /content/drive/MyDrive/Colab Notebooks/Image_rec/coco_dataset

# %%
# 下载 2017 年份的图片（以 Val2017 和 Annotations 为例，Train2017 很大，方法相同）
# !wget http://images.cocodataset.org/zips/train2017.zip
# !wget http://images.cocodataset.org/zips/val2017.zip
# !wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip

# 解压文件
# !unzip -q train2017.zip
# !unzip -q val2017.zip
# !unzip -q annotations_trainval2017.zip
# Out:
# --2026-01-05 11:39:53--  http://images.cocodataset.org/zips/train2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 54.231.138.137, 16.15.176.200, 52.216.244.4, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|54.231.138.137|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19336861798 (18G) [application/zip]
# Saving to: ‘train2017.zip’
#
# train2017.zip       100%[===================>]  18.01G  52.2MB/s    in 6m 16s
#
# 2026-01-05 11:46:09 (49.1 MB/s) - ‘train2017.zip’ saved [19336861798/19336861798]
#
# --2026-01-05 11:46:10--  http://images.cocodataset.org/zips/val2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.65.124, 16.15.183.47, 3.5.25.72, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.65.124|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 815585330 (778M) [application/zip]
# Saving to: ‘val2017.zip’
#
# val2017.zip         100%[===================>] 777.80M  23.9MB/s    in 23s
#
# 2026-01-05 11:46:33 (34.4 MB/s) - ‘val2017.zip’ saved [815585330/815585330]
#
# --2026-01-05 11:46:33--  http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.33.76, 52.217.66.164, 54.231.197.25, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.33.76|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252907541 (241M) [application/zip]
# Saving to: ‘annotations_trainval2017.zip’
#
# annotations_trainva 100%[===================>] 241.19M  16.3MB/s    in 12s
#
# 2026-01-05 11:46:46 (20.2 MB/s) - ‘annotations_trainval2017.zip’ saved [252907541/252907541]
